# %%
import yfinance as yf
from grab2 import Grab

# %% [markdown]
# ## AAPL

# %%
msft = yf.Ticker("AAPL")
hist = msft.history(start="2005-01-01", end="2022-11-01")
hist = hist[["Open", "High", "Low", "Close"]]
algo = Grab(hist, 50, 10, 20)
algo.trade()
algo.feed.to_csv("aapl_optimal_trade_full.csv")
algo.fixed_feed.to_csv("aapl_fixed_trade_full.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lyf/projects/MQF/STAT-972/paper/grab2.ipynb Cell 3 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/lyf/projects/MQF/STAT-972/paper/grab2.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> hist = hist[["Open", "High", "Low", "Close"]]
#       <a href='vscode-notebook-cell:/Users/lyf/projects/MQF/STAT-972/paper/grab2.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> algo = Grab(hist, 50, 10, 20)
# ----> <a href='vscode-notebook-cell:/Users/lyf/projects/MQF/STAT-972/paper/grab2.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> algo.trade()
#       <a href='vscode-notebook-cell:/Users/lyf/projects/MQF/STAT-972/paper/grab2.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> algo.feed.to_csv("aapl_optimal_trade_full.csv")
#       <a href='vscode-notebook-cell:/Users/lyf/projects/MQF/STAT-972/paper/grab2.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> algo.fixed_feed.to_csv("aapl_fixed_trade_full.csv")
#
# File ~/projects/MQF/STAT-972/paper/grab2.py:210, in Grab.trade(self)
#     208 N_far, N_near = self.find_optimal_N()
#     209 # update the trading states for all combinations of parameters
# --> 210 if self.update_bt(ts) == False:
#     211     continue
#     212 # update fixed_feed
#
# File ~/projects/MQF/STAT-972/paper/grab2.py:185, in Grab.update_bt(self, ts)
#     183 cash = self.bt_cash[N_far - 2][N_near - 1]
#     184 trend = self.bt_trend[N_far - 2][N_near - 1]
# --> 185 trend, shares, price, cash, pnl, far_support, far_resistance, near_support, near_resistance = self.single_trade(
#     186     ts, trend, shares, cash, N_far, N_near)
#     187 self.bt_ts = ts
#     188 self.bt_trend[N_far - 2][N_near - 1] = trend
#
# File ~/projects/MQF/STAT-972/paper/grab2.py:86, in Grab.single_trade(self, ts, trend, shares, cash, N_far, N_near)
#      83 # calculate the far and near resistance and support level
#      84 # for the next trade
#      85 far_support = far["Low"].min()
# ---> 86 far_resistance = far["High"].max()
#      87 near_support = near["Low"].min()
#      88 near_resistance = near["High"].max()
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/generic.py:10819, in NDFrame._add_numeric_operations.<locals>.max(self, axis, skipna, level, numeric_only, **kwargs)
#   10806 @doc(
#   10807     _num_doc,
#   10808     desc="Return the maximum of the values over the requested axis.\n\n"
#    (...)
#   10817 )
#   10818 def max(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10819     return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/generic.py:10364, in NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   10363 def max(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10364     return self._stat_function(
#   10365         "max", nanops.nanmax, axis, skipna, level, numeric_only, **kwargs
#   10366     )
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/generic.py:10354, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10344     warnings.warn(
#   10345         "Using the level keyword in DataFrame and Series aggregations is "
#   10346         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10349         stacklevel=4,
#   10350     )
#   10351     return self._agg_by_level(
#   10352         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10353     )
# > 10354 return self._reduce(
#   10355     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356 )
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/series.py:4392, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4388     raise NotImplementedError(
#    4389         f"Series.{name} does not implement numeric_only."
#    4390     )
#    4391 with np.errstate(all="ignore"):
# -> 4392     return op(delegate, skipna=skipna, **kwds)
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/nanops.py:1006, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#     996 @bottleneck_switch(name="nan" + meth)
#     997 @_datetimelike_compat
#     998 def reduction(
#    (...)
#    1003     mask: np.ndarray | None = None,
#    1004 ) -> Dtype:
# -> 1006     values, mask, dtype, dtype_max, fill_value = _get_values(
#    1007         values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1008     )
#    1010     if (axis is not None and values.shape[axis] == 0) or values.size == 0:
#    1011         try:
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/nanops.py:308, in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     304 # error: Incompatible types in assignment (expression has type "Union[Any,
#     305 # Union[ExtensionArray, ndarray]]", variable has type "ndarray")
#     306 values = extract_array(values, extract_numpy=True)  # type: ignore[assignment]
# --> 308 mask = _maybe_get_mask(values, skipna, mask)
#     310 dtype = values.dtype
#     312 datetimelike = False
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/nanops.py:252, in _maybe_get_mask(values, skipna, mask)
#     249         return None
#     251     if skipna or needs_i8_conversion(values.dtype):
# --> 252         mask = isna(values)
#     254 return mask
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:138, in isna(obj)
#      61 def isna(obj):
#      62     """
#      63     Detect missing values for an array-like object.
#      64
#    (...)
#     136     Name: 1, dtype: bool
#     137     """
# --> 138     return _isna(obj)
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:171, in _isna(obj, inf_as_na)
#     169     return False
#     170 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 171     return _isna_array(obj, inf_as_na=inf_as_na)
#     172 elif isinstance(obj, (ABCSeries, ABCIndex)):
#     173     result = _isna_array(obj._values, inf_as_na=inf_as_na)
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:245, in _isna_array(values, inf_as_na)
#     243     else:
#     244         result = values.isna()
# --> 245 elif is_string_dtype(dtype):
#     246     result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     247 elif needs_i8_conversion(dtype):
#     248     # this is the NaT pattern
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/dtypes/common.py:571, in is_string_dtype(arr_or_dtype)
#     568     is_excluded_checks = (is_period_dtype, is_interval_dtype, is_categorical_dtype)
#     569     return any(is_excluded(dtype) for is_excluded in is_excluded_checks)
# --> 571 return _is_dtype(arr_or_dtype, condition)
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/dtypes/common.py:1537, in _is_dtype(arr_or_dtype, condition)
#    1535     return False
#    1536 try:
# -> 1537     dtype = get_dtype(arr_or_dtype)
#    1538 except (TypeError, ValueError):
#    1539     return False
#
# File ~/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/pandas/core/dtypes/common.py:1566, in get_dtype(arr_or_dtype)
#    1563     raise TypeError("Cannot deduce dtype from null object")
#    1565 # fastpath
# -> 1566 elif isinstance(arr_or_dtype, np.dtype):
#    1567     return arr_or_dtype
#    1568 elif isinstance(arr_or_dtype, type):
#
# KeyboardInterrupt:

# %%
algo.plot2(algo.feed)
algo.plot(algo.feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
algo.plot2(algo.fixed_feed)
algo.plot(algo.fixed_feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %% [markdown]
# ## ADMP

# %%
msft = yf.Ticker("ADMP")
hist = msft.history(start="2005-01-01", end="2022-11-01")
hist = hist[["Open", "High", "Low", "Close"]]
algo = Grab(hist, 50, 10, 20)
algo.trade()
algo.feed.to_csv("admp_optimal_trade_full.csv")
algo.fixed_feed.to_csv("admp_fixed_trade_full.csv")

# %%
algo.plot2(algo.feed)
algo.plot(algo.feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
algo.plot2(algo.fixed_feed)
algo.plot(algo.fixed_feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %% [markdown]
# ## MSFT

# %%
msft = yf.Ticker("MSFT")
hist = msft.history(start="2005-01-01", end="2022-11-01")
hist = hist[["Open", "High", "Low", "Close"]]
algo = Grab(hist, 50, 10, 20)
algo.trade()
algo.feed.to_csv("msft_optimal_trade_full.csv")
algo.fixed_feed.to_csv("msft_fixed_trade_full.csv")

# %%
algo.plot2(algo.feed)
algo.plot(algo.feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
algo.plot2(algo.fixed_feed)
algo.plot(algo.fixed_feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %% [markdown]
# ## TSLA

# %%
msft = yf.Ticker("TSLA")
hist = msft.history(start="2005-01-01", end="2022-11-01")
hist = hist[["Open", "High", "Low", "Close"]]
algo = Grab(hist, 50, 10, 20)
algo.trade()
algo.feed.to_csv("tsla_optimal_trade_full.csv")
algo.fixed_feed.to_csv("tsla_fixed_trade_full.csv")

# %%
algo.plot2(algo.feed)
algo.plot(algo.feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
algo.plot2(algo.fixed_feed)
algo.plot(algo.fixed_feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %% [markdown]
# ## SPY

# %%
msft = yf.Ticker("SPY")
hist = msft.history(start="2005-01-01", end="2022-11-01")
hist = hist[["Open", "High", "Low", "Close"]]
algo = Grab(hist, 50, 10, 20)
algo.trade()
algo.feed.to_csv("spy_optimal_trade_full.csv")
algo.fixed_feed.to_csv("spy_fixed_trade_full.csv")

# %%
algo.plot2(algo.feed)
algo.plot(algo.feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
algo.plot2(algo.fixed_feed)
algo.plot(algo.fixed_feed)
# Out:
# /Users/lyf/opt/miniconda3/envs/ftx/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
